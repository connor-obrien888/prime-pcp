# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import prime.prime_lib.primesw.prime as pr

sw_data = pd.read_hdf('data/sw_outputs.h5', 'prime_predict_full') #Load solar wind data from PRIME at MMS's position
mms_data = pd.read_hdf('data/mms_data.h5', 'targets') #Load MMS data
wind_data = pd.read_hdf('data/wind_data_full.h5', 'wind_combined') #Load Wind data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 8
#       6 sw_data = pd.read_hdf('data/sw_outputs.h5', 'prime_predict_full') #Load solar wind data from PRIME at MMS's position
#       7 mms_data = pd.read_hdf('data/mms_data.h5', 'targets') #Load MMS data
# ----> 8 wind_data = pd.read_hdf('data/wind_data_full.h5', 'wind_combined') #Load Wind data
#
# File ~/.cache/pypoetry/virtualenvs/prime-pcp-R9PMZO5N-py3.9/lib/python3.9/site-packages/pandas/io/pytables.py:452, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     447                 raise ValueError(
#     448                     "key must be provided when HDF5 "
#     449                     "file contains multiple datasets."
#     450                 )
#     451         key = candidate_only_group._v_pathname
# --> 452     return store.select(
# ...

# %%
store = pd.HDFStore('data/wind_data_full.h5', mode = 'r')
store.keys()
# Out:
# ['/mfi_raw', '/prime_full', '/swe_raw', '/wind_full']

# %%
store['wind_full']
# Out:
#                 Ni     Vi_xgse    Vi_ygse   Vi_zgse        Vth    vflag  \
# 0        11.552779 -440.943115 -59.691292  5.275811  28.958385      2.0
# 1        11.706051 -440.078644 -60.615494  3.433239  29.015652      2.0
# 2        11.859322 -439.214172 -61.539692  1.590666  29.072916      2.0
# 3        12.239519 -441.489136 -73.520584 -0.598664  30.993860      2.0
# 4        11.862305 -442.501526 -61.800797  4.074720  27.650091      2.0
# ...            ...         ...        ...       ...        ...      ...
# 8993191   6.401696 -380.359528 -12.840384  2.286631  29.025087  14338.0
# 8993192   6.446248 -378.524048 -16.043329  1.722894  29.545563  14342.0
# 8993193   6.490799 -376.688568 -19.246275  1.159157  30.066040  14342.0
# 8993194   6.535351 -374.853088 -22.449221  0.595419  30.586515  14338.0
# 8993195   6.535351 -374.853088 -22.449221  0.595419  30.586515  14338.0
#
#           niflag      R_xgse      R_ygse    R_zgse    B_xgsm    B_ygsm  \
# ...
